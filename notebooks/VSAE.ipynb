# %%
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import numpy as np
from scipy.stats import entropy
import torch
from torch.utils.data import DataLoader, TensorDataset
from logistic_regression_classifier import evaluate_per_neuron_1vsall_test

# %%
pkl_path = './logs_vanilla_sae_07_02/all_results_vanilla_sae.pkl'

# %%
with open(pkl_path, "rb") as f:
    all_results = pickle.load(f)

pure_digit_coverage = {}

for sae_name, results in all_results.items():
    auc_matrix = results["auc_matrix"]
    neuron_df = results["per_neuron_df"]
    
    count_per_neuron = (auc_matrix > 0.95).sum(axis=1)
    
    pure_neurons = count_per_neuron[count_per_neuron == 1].index
    
    digits_represented = neuron_df.loc[pure_neurons, "best_digit"]
    
    digit_counts = digits_represented.value_counts().sort_index()
    
    pure_digit_coverage[sae_name] = {
        "n_digits_represented": digit_counts.count(),
        "digit_counts": digit_counts.to_dict()
    }

for sae, info in pure_digit_coverage.items():
    print(f"\n{sae}:")
    print(f"  Unique digits with ≥1 pure neuron: {info['n_digits_represented']}")
    print(f"  Digit breakdown: {info['digit_counts']}")
# Out:
# vanilla_sae_512_12_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 20, 2: 13, 3: 9, 4: 5, 5: 8, 6: 8, 7: 6, 9: 1}
#
# vanilla_sae_512_12_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 16, 2: 13, 3: 6, 4: 4, 5: 6, 6: 7, 7: 8, 9: 1}
#
# vanilla_sae_512_12_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 8, 1: 16, 2: 13, 3: 6, 4: 5, 5: 6, 6: 7, 7: 8, 9: 1}
#
# vanilla_sae_512_4_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 16, 1: 20, 2: 8, 3: 9, 4: 11, 5: 9, 6: 20, 7: 10, 9: 1}
#
# vanilla_sae_512_4_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 17, 1: 21, 2: 9, 3: 8, 4: 11, 5: 9, 6: 19, 7: 10, 9: 1}
#
# vanilla_sae_512_4_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 17, 1: 24, 2: 10, 3: 8, 4: 10, 5: 9, 6: 18, 7: 9, 9: 2}
#
# vanilla_sae_512_5_best_loss:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 9, 1: 21, 2: 12, 3: 4, 4: 9, 5: 4, 6: 13, 7: 8, 8: 1, 9: 1}
#
# vanilla_sae_512_5_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 11, 1: 21, 2: 13, 3: 5, 4: 12, 5: 4, 6: 12, 7: 7}
#
# vanilla_sae_512_5_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 10, 1: 23, 2: 13, 3: 5, 4: 12, 5: 4, 6: 12, 7: 8}
#
# vanilla_sae_512_6_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 14, 1: 20, 2: 9, 3: 6, 4: 8, 5: 8, 6: 22, 7: 10, 9: 3}
#
# vanilla_sae_512_6_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 12, 1: 15, 2: 9, 3: 6, 4: 6, 5: 6, 6: 25, 7: 11, 9: 4}
#
# vanilla_sae_512_6_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 12, 1: 15, 2: 9, 3: 6, 4: 6, 5: 6, 6: 25, 7: 11, 9: 4}
#
# vanilla_sae_512_0_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 13, 1: 21, 2: 5, 3: 7, 4: 10, 5: 8, 6: 22, 7: 7, 9: 2}
#
# vanilla_sae_512_0_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 15, 1: 21, 2: 6, 3: 6, 4: 9, 5: 8, 6: 25, 7: 7, 9: 2}
#
# vanilla_sae_512_0_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 16, 1: 23, 2: 5, 3: 6, 4: 9, 5: 8, 6: 26, 7: 7, 9: 2}
#
# vanilla_sae_512_18_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 7, 1: 9, 2: 6, 4: 4, 5: 4, 6: 5, 7: 9, 8: 1}
#
# vanilla_sae_512_18_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 7, 1: 9, 2: 6, 4: 4, 5: 4, 6: 5, 7: 9, 8: 1}
#
# vanilla_sae_512_18_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 7, 1: 9, 2: 6, 4: 4, 5: 4, 6: 5, 7: 9, 8: 1}
#
# vanilla_sae_512_19_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 9, 1: 10, 2: 5, 3: 6, 4: 5, 5: 6, 6: 5, 7: 6}
#
# vanilla_sae_512_19_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 9, 1: 10, 2: 5, 3: 6, 4: 5, 5: 6, 6: 5, 7: 6}
#
# vanilla_sae_512_19_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 9, 1: 10, 2: 5, 3: 6, 4: 5, 5: 6, 6: 5, 7: 6}
#
# vanilla_sae_512_11_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 8, 1: 22, 2: 8, 3: 5, 4: 6, 5: 7, 6: 6, 7: 7}
#
# vanilla_sae_512_11_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 9, 1: 17, 2: 11, 3: 5, 4: 8, 5: 7, 6: 6, 7: 7}
#
# vanilla_sae_512_11_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 10, 1: 16, 2: 12, 3: 5, 4: 8, 5: 7, 6: 7, 7: 7}
#
# vanilla_sae_512_10_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 17, 2: 6, 3: 1, 4: 9, 5: 6, 6: 10, 7: 12, 9: 2}
#
# vanilla_sae_512_10_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 11, 1: 14, 2: 8, 3: 1, 4: 5, 5: 7, 6: 9, 7: 9, 9: 4}
#
# vanilla_sae_512_10_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 11, 1: 14, 2: 8, 3: 1, 4: 5, 5: 7, 6: 9, 7: 9, 9: 4}
#
# vanilla_sae_512_7_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 16, 1: 17, 2: 13, 3: 1, 4: 10, 5: 8, 6: 17, 7: 14, 9: 3}
#
# vanilla_sae_512_7_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 16, 1: 14, 2: 13, 4: 8, 5: 10, 6: 13, 7: 14, 8: 1, 9: 3}
#
# vanilla_sae_512_7_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 16, 1: 14, 2: 13, 4: 8, 5: 10, 6: 13, 7: 14, 8: 1, 9: 3}
#
# vanilla_sae_512_14_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 14, 2: 8, 3: 4, 4: 8, 5: 10, 6: 9, 7: 17, 9: 2}
#
# vanilla_sae_512_14_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 15, 2: 9, 3: 4, 4: 9, 5: 11, 6: 9, 7: 17, 9: 2}
#
# vanilla_sae_512_14_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 7, 1: 15, 2: 9, 3: 4, 4: 9, 5: 11, 6: 9, 7: 17, 9: 2}
#
# vanilla_sae_512_16_best_loss:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 6, 1: 10, 2: 9, 3: 1, 4: 7, 5: 8, 6: 8, 7: 11, 8: 1, 9: 1}
#
# vanilla_sae_512_16_best_both:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 6, 1: 10, 2: 9, 3: 1, 4: 7, 5: 8, 6: 8, 7: 11, 8: 1, 9: 1}
#
# vanilla_sae_512_16_best_dead10:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 6, 1: 10, 2: 9, 3: 1, 4: 7, 5: 8, 6: 8, 7: 11, 8: 1, 9: 1}
#
# vanilla_sae_512_3_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 24, 1: 23, 2: 6, 3: 8, 4: 10, 5: 7, 6: 20, 7: 10}
#
# vanilla_sae_512_3_best_both:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 21, 1: 23, 2: 6, 3: 6, 4: 9, 5: 7, 6: 21, 7: 10, 8: 2, 9: 1}
#
# vanilla_sae_512_3_best_dead10:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 21, 1: 23, 2: 6, 3: 6, 4: 9, 5: 7, 6: 21, 7: 10, 8: 2, 9: 1}
#
# vanilla_sae_512_15_best_loss:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 11, 1: 11, 2: 10, 3: 6, 4: 5, 5: 4, 6: 6, 7: 7, 8: 1, 9: 2}
#
# vanilla_sae_512_15_best_both:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 11, 1: 11, 2: 10, 3: 6, 4: 5, 5: 4, 6: 6, 7: 7, 8: 1, 9: 2}
#
# vanilla_sae_512_15_best_dead10:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 11, 1: 12, 2: 10, 3: 6, 4: 5, 5: 4, 6: 6, 7: 7, 8: 1, 9: 2}
#
# vanilla_sae_512_13_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 8, 1: 14, 2: 8, 3: 6, 4: 6, 5: 6, 6: 7, 7: 11}
#
# vanilla_sae_512_13_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 7, 1: 15, 2: 7, 3: 7, 4: 6, 5: 6, 6: 9, 7: 9}
#
# vanilla_sae_512_13_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 7, 1: 15, 2: 7, 3: 7, 4: 6, 5: 6, 6: 9, 7: 9}
#
# vanilla_sae_512_8_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 18, 1: 21, 2: 8, 3: 3, 4: 11, 5: 5, 6: 13, 7: 9, 9: 4}
#
# vanilla_sae_512_8_best_both:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 19, 1: 19, 2: 7, 3: 3, 4: 10, 5: 6, 6: 11, 7: 8, 9: 4}
#
# vanilla_sae_512_8_best_dead10:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 18, 1: 21, 2: 7, 3: 3, 4: 11, 5: 6, 6: 12, 7: 8, 9: 4}
#
# vanilla_sae_512_1_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 17, 1: 19, 2: 7, 3: 7, 4: 6, 5: 11, 6: 16, 7: 11, 8: 1}
#
# vanilla_sae_512_1_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 17, 1: 26, 2: 7, 3: 7, 4: 7, 5: 11, 6: 16, 7: 13}
#
# vanilla_sae_512_1_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 17, 1: 26, 2: 7, 3: 7, 4: 7, 5: 11, 6: 16, 7: 13}
#
# vanilla_sae_512_2_best_loss:
#   Unique digits with ≥1 pure neuron: 9
#   Digit breakdown: {0: 13, 1: 21, 2: 14, 3: 10, 4: 17, 5: 13, 6: 15, 7: 12, 8: 1}
#
# vanilla_sae_512_2_best_both:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 15, 1: 21, 2: 15, 3: 8, 4: 15, 5: 14, 6: 13, 7: 10, 8: 1, 9: 1}
#
# vanilla_sae_512_2_best_dead10:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 15, 1: 21, 2: 15, 3: 8, 4: 15, 5: 14, 6: 13, 7: 10, 8: 1, 9: 1}
#
# vanilla_sae_512_17_best_loss:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 6, 1: 10, 2: 13, 3: 5, 4: 4, 5: 5, 6: 8, 7: 8}
#
# vanilla_sae_512_17_best_both:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 6, 1: 10, 2: 13, 3: 5, 4: 4, 5: 5, 6: 8, 7: 8}
#
# vanilla_sae_512_17_best_dead10:
#   Unique digits with ≥1 pure neuron: 8
#   Digit breakdown: {0: 6, 1: 10, 2: 13, 3: 5, 4: 4, 5: 5, 6: 8, 7: 8}
#
# vanilla_sae_512_9_best_loss:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 18, 1: 20, 2: 6, 3: 5, 4: 8, 5: 10, 6: 9, 7: 17, 8: 1, 9: 3}
#
# vanilla_sae_512_9_best_both:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 19, 1: 20, 2: 6, 3: 5, 4: 10, 5: 8, 6: 9, 7: 18, 8: 1, 9: 2}
#
# vanilla_sae_512_9_best_dead10:
#   Unique digits with ≥1 pure neuron: 10
#   Digit breakdown: {0: 19, 1: 20, 2: 6, 3: 5, 4: 10, 5: 8, 6: 9, 7: 18, 8: 1, 9: 2}

# %%
sae_digit_counts = {}
auc_matrix = all_results['reanim_vanilla_sae_512_1_best_loss']['auc_matrix']
neuron_df = all_results['reanim_vanilla_sae_512_1_best_loss']['per_neuron_df']
summary_df = all_results['reanim_vanilla_sae_512_1_best_loss']['sae_summary']

# %%
auc_matrix[(auc_matrix > 0.99).sum(axis=1) == 1]
# Out:
# digit              0         1         2         3         4         5  \
# neuron_idx
# 26          0.401400  0.536444  0.438508  0.650071  0.544228  0.659291
# 87          0.995789  0.676491  0.627509  0.856692  0.590083  0.846534
# 106         0.524424  0.367404  0.677354  0.698036  0.462012  0.454480
# 155         0.828746  0.707402  0.643444  0.726661  0.476200  0.593646
# 245         0.469475  0.605238  0.648989  0.657042  0.990367  0.625733
# 254         0.572207  0.991850  0.728557  0.933389  0.810942  0.822980
# 284         0.583801  0.995052  0.511501  0.648056  0.596309  0.822709
# 418         0.568096  0.742952  0.619330  0.649922  0.517172  0.516915
# 461         0.919995  0.990193  0.579078  0.633192  0.773423  0.676223
# 473         0.605521  0.996801  0.571621  0.528224  0.567566  0.596440
# 477         0.671064  0.991050  0.476307  0.520603  0.596302  0.752205
#
# digit              6         7         8         9
# neuron_idx
# 26          0.996962  0.705615  0.652570  0.704578
# 87          0.689607  0.431025  0.452051  0.602598
# 106         0.997837  0.812481  0.516968  0.828838
# 155         0.990157  0.787508  0.652365  0.780943
# 245         0.647799  0.502739  0.652552  0.463140
# 254         0.598358  0.561820  0.504194  0.521177
# 284         0.795392  0.728699  0.621800  0.669000
# 418         0.994046  0.759664  0.602295  0.755611
# 461         0.680551  0.593774  0.682128  0.580373
# 473         0.605377  0.434782  0.576330  0.581909
# 477         0.846831  0.639164  0.687602  0.757874

# %%
ckpt = torch.load('log_06_10/new_test_activation.pt')

fc1 = ckpt["fc1"]
labels = ckpt["labels"]

ckpt_train = torch.load('log_06_10/train_activation.pt')

fc1_train = ckpt_train["fc1"]
labels_train = ckpt_train["labels"]

sae = torch.load('logs_test/reanim_vanilla_sae_512_1/best_loss.pth')
device = torch.device("cuda")
sae.to(device)
sae.eval()

with torch.no_grad():
    pre_codes_train, codes_train = sae.encode(fc1_train.to(device))
    activations_train = codes_train.cpu()

    pre_codes, codes = sae.encode(fc1.to(device))
    activations = codes.cpu()

    results_df = evaluate_per_neuron_1vsall_test(activations_train, activations, labels_train.cpu(), labels.cpu())


auc_test_matrix = results_df.pivot(index='neuron_idx', columns='digit', values='auc_test').fillna(0)
auc_train_matrix = results_df.pivot(index='neuron_idx', columns='digit', values='auc_train').fillna(0)
# Out:
# /tmp/ipykernel_3416512/2946044980.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load('log_06_10/new_test_activation.pt')
# /tmp/ipykernel_3416512/2946044980.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt_train = torch.load('log_06_10/train_activation.pt')
# /tmp/ipykernel_3416512/2946044980.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sae = torch.load('logs_test/reanim_vanilla_sae_512_1/best_loss.pth')

# %%
fc1.shape
# Out:
# torch.Size([10000, 128])

# %%
auc_train_matrix[(auc_train_matrix > 0.95).sum(axis=1) == 1]
# Out:
# digit              0         1         2         3         4         5  \
# neuron_idx
# 11          0.724195  0.521490  0.729304  0.585780  0.766392  0.729434
# 21          0.566522  0.433775  0.494638  0.675959  0.532389  0.720831
# 23          0.434530  0.815377  0.607963  0.659020  0.745027  0.653894
# 32          0.980501  0.470281  0.431496  0.727985  0.641466  0.656493
# 33          0.606084  0.492114  0.579669  0.501165  0.815909  0.670059
# ...              ...       ...       ...       ...       ...       ...
# 487         0.566448  0.669221  0.646163  0.530360  0.791465  0.962027
# 498         0.731248  0.730014  0.970025  0.504836  0.584685  0.696526
# 500         0.534121  0.785816  0.548889  0.585916  0.727008  0.689364
# 506         0.969262  0.789892  0.756173  0.687615  0.826140  0.697548
# 511         0.781903  0.720527  0.656400  0.878584  0.637505  0.962352
#
# digit              6         7         8         9
# neuron_idx
# 11          0.691620  0.974059  0.761303  0.588561
# 21          0.720580  0.955547  0.535722  0.683931
# 23          0.781547  0.857918  0.605013  0.968502
# 32          0.736354  0.606880  0.720773  0.747770
# 33          0.967881  0.663371  0.590118  0.746754
# ...              ...       ...       ...       ...
# 487         0.506668  0.725033  0.825827  0.664919
# 498         0.658162  0.612207  0.758777  0.678837
# 500         0.991427  0.850745  0.557181  0.861950
# 506         0.643780  0.547293  0.680493  0.650259
# 511         0.555776  0.782902  0.784178  0.573216
#
# [62 rows x 10 columns]

# %%
printauc_test_matrix[(auc_test_matrix > 0.95).sum(axis=1) == 1]
# Out:
# digit              0         1         2         3         4         5  \
# neuron_idx
# 11          0.728827  0.543083  0.743449  0.603207  0.779193  0.725740
# 16          0.647894  0.509660  0.956481  0.802988  0.857450  0.749111
# 21          0.568344  0.438283  0.486256  0.676846  0.531624  0.715413
# 23          0.431027  0.818350  0.633179  0.675383  0.753859  0.662758
# 30          0.573772  0.793086  0.496090  0.705850  0.547432  0.953536
# ...              ...       ...       ...       ...       ...       ...
# 487         0.583088  0.676297  0.665059  0.511726  0.787707  0.966194
# 498         0.724952  0.718191  0.967928  0.498383  0.566675  0.715021
# 500         0.528435  0.785877  0.556453  0.574093  0.725407  0.710217
# 506         0.969261  0.789165  0.769256  0.677252  0.822576  0.703729
# 511         0.800061  0.702956  0.656277  0.880909  0.630157  0.962426
#
# digit              6         7         8         9
# neuron_idx
# 11          0.645149  0.976195  0.766415  0.567084
# 16          0.615616  0.635426  0.760842  0.825624
# 21          0.714942  0.962865  0.551981  0.669930
# 23          0.753025  0.852571  0.592816  0.968326
# 30          0.862997  0.567707  0.782976  0.531716
# ...              ...       ...       ...       ...
# 487         0.527880  0.707038  0.820778  0.644842
# 498         0.685569  0.592429  0.775303  0.690749
# 500         0.989993  0.857001  0.548552  0.862432
# 506         0.682807  0.521102  0.667184  0.649139
# 511         0.586389  0.777458  0.788559  0.593533
#
# [70 rows x 10 columns]
